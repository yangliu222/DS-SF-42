# %% [markdown]
# # Telecomm EDA project

# %% [markdown]
# ### Import Libraries

# %%
# !pip install folium
# !pip install geopy
# Out:
# Requirement already satisfied: folium in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: branca in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->folium)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.6/site-packages

# %%
import numpy as np
import pandas as pd
import folium as folium
from geopy.geocoders import Nominatim

# %matplotlib inline

# %% [markdown]
# # Cleanup

# %% [markdown]
# ### Turn the CSV into a PD Dataframe

# %%
df = pd.read_csv("datasets/metadata.csv").drop(["Cell Cgi"], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10476 entries, 0 to 10475
# Data columns (total 6 columns):
# Cell Tower Location     10476 non-null object
# Comm Identifier         1374 non-null object
# Comm Timedate String    10476 non-null object
# Comm Type               10476 non-null object
# Latitude                10476 non-null float64
# Longitude               10476 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 491.1+ KB

# %% [markdown]
# ### Turn Datetime String into a numpy Datetime Object

# %%
df["Datetime"] = pd.to_datetime(df["Comm Timedate String"], infer_datetime_format=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10476 entries, 0 to 10475
# Data columns (total 7 columns):
# Cell Tower Location     10476 non-null object
# Comm Identifier         1374 non-null object
# Comm Timedate String    10476 non-null object
# Comm Type               10476 non-null object
# Latitude                10476 non-null float64
# Longitude               10476 non-null float64
# Datetime                10476 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 573.0+ KB

# %% [markdown]
# ### Make day of week column

# %%
df['Day of Week'] = df['Datetime'].dt.weekday_name

# %% [markdown]
# ### Make the coordinates Folium Friendly :)

# %%
df['Location']=list(zip(df.Latitude,df.Longitude))

# %% [markdown]
# ### Cleanup and reorganize DataFrame

# %%
df = df[['Datetime', 'Day of Week', 'Comm Identifier', 'Comm Type', 'Cell Tower Location', 'Location']]
df.head()
# Out:
#              Datetime Day of Week                           Comm Identifier  \
# 0 2014-04-01 09:40:00     Tuesday  f1a6836c0b7a3415a19a90fdd6f0ae18484d6d1e
# 1 2014-04-01 09:42:00     Tuesday  62157ccf2910019ffd915b11fa037243b75c1624
# 2 2014-04-01 13:13:00     Tuesday  c8f92bd0f4e6fb45ed7fce96fc831b283db2b642
# 3 2014-04-01 13:13:00     Tuesday  f1a6836c0b7a3415a19a90fdd6f0ae18484d6d1e
# 4 2014-04-01 17:27:00     Tuesday  f1a6836c0b7a3415a19a90fdd6f0ae18484d6d1e
#
#   Comm Type Cell Tower Location                     Location
# 0     Phone          REDFERN TE  (-33.89293336, 151.2022962)
# 1     Phone          REDFERN TE  (-33.89293336, 151.2022962)
# 2     Phone         HAYMARKET #  (-33.88032891, 151.2056904)
# 3     Phone         HAYMARKET #  (-33.88032891, 151.2056904)
# 4     Phone         HAYMARKET #  (-33.88032891, 151.2056904)

# %% [markdown]
# ### Shorten Comm Identifier

# %%
df["Comm Identifier"] = df["Comm Identifier"].str[:10]

df.head()
# Out:
#              Datetime Day of Week Comm Identifier Comm Type  \
# 0 2014-04-01 09:40:00     Tuesday      f1a6836c0b     Phone
# 1 2014-04-01 09:42:00     Tuesday      62157ccf29     Phone
# 2 2014-04-01 13:13:00     Tuesday      c8f92bd0f4     Phone
# 3 2014-04-01 13:13:00     Tuesday      f1a6836c0b     Phone
# 4 2014-04-01 17:27:00     Tuesday      f1a6836c0b     Phone
#
#   Cell Tower Location                     Location
# 0          REDFERN TE  (-33.89293336, 151.2022962)
# 1          REDFERN TE  (-33.89293336, 151.2022962)
# 2         HAYMARKET #  (-33.88032891, 151.2056904)
# 3         HAYMARKET #  (-33.88032891, 151.2056904)
# 4         HAYMARKET #  (-33.88032891, 151.2056904)

# %% [markdown]
# # EDA

# %% [markdown]
# ### Where this individual spends the most time.
#
# They can usually be found in Sydney Australia.
#
# - spends both weekend and weekday time near Amazonia Martial Arts, his top location overall.  this is likely his home
# - spends a lot of weekday time at IFGF Sydney (a church), maybe volunteering?
# - parks at City Parking in Haymarket on weekdays, rarely on weekends.  this is probably near where he works

# %%
df['Location'].dropna().value_counts().head(10)
# Out:
# (-33.78815, 151.26654)         4301
# (-33.88417103, 151.20235)      1084
# (-42.84338, 147.29569)          723
# (-33.89293336, 151.2022962)     712
# (-33.88032891, 151.2056904)     563
# (-42.85984, 147.29215)          501
# (-33.779333, 151.276901)        465
# (-33.79661, 151.27756)          454
# (-33.796679, 151.285293)        231
# (-42.85307, 147.31532)          197
# Name: Location, dtype: int64

# %% [markdown]
# ### 4301
# -33.788150, 151.266540 = Amazonia Martial Arts Club (Manly Beach
#
# ### 1084
# -33.884171, 151.202350 = IFGF Sydney (a church) (Haymarket, Sydney)
#
# ### 723
# -42.843380, 147.295690 = Shopping Mall, Intercity Cycleway (Tasmania)
#
# ### 712
# -33.892933, 151.202296 = Office Building outside fire station (Redfern, Sydney)
#
# ### 563
# -33.880329, 151.205690 = City Parking (Haymarket, Sydney)

# %% [markdown]
# There are four distinct periods of time where the individual goes to Tasmania:
# - 5/2/2014 to 5/4/2014
# - 8/10/2014 to 8/12/2014
# - 11/12/2014 to 11/15/2014
# - 12/20/2014 to 12/26/2014

# %% [markdown]
# ### Weekdays vs Weekends

# %%
# build a mask to select days 5 and 6 (saturday, sunday)
df.loc[~df.Datetime.dt.weekday.isin([5,6])]
# Out:
#                  Datetime Day of Week Comm Identifier Comm Type  \
# 0     2014-04-01 09:40:00     Tuesday      f1a6836c0b     Phone
# 1     2014-04-01 09:42:00     Tuesday      62157ccf29     Phone
# 2     2014-04-01 13:13:00     Tuesday      c8f92bd0f4     Phone
# 3     2014-04-01 13:13:00     Tuesday      f1a6836c0b     Phone
# 4     2014-04-01 17:27:00     Tuesday      f1a6836c0b     Phone
# 143                 REDFERN TE  (-33.89293336, 151.2022962)
# 144                 REDFERN TE  (-33.89293336, 151.2022962)
# 145                 REDFERN TE  (-33.89293336, 151.2022962)
# 146                 REDFERN TE  (-33.89293336, 151.2022962)
# 147                CHIPPENDALE    (-33.88417103, 151.20235)
# 174                   NEW TOWN       (-42.85307, 147.31532)
# 175              SUNDERLAND ST       (-42.84338, 147.29569)
# 176             HOBART AIRPORT       (-42.83762, 147.50575)
# 177             HOBART AIRPORT       (-42.83762, 147.50575)
# 178             HOBART AIRPORT       (-42.83762, 147.50575)
# 179             HOBART AIRPORT       (-42.83762, 147.50575)
# 180             HOBART AIRPORT       (-42.83762, 147.50575)
# 181               MOUNT RUMNEY         (-42.8606, 147.4542)
# 217                 REDFERN TE  (-33.89293336, 151.2022962)
# 218                 REDFERN TE  (-33.89293336, 151.2022962)
# ...                        ...                          ...
# 10169               REDFERN TE  (-33.89293336, 151.2022962)
# 10170               REDFERN TE  (-33.89293336, 151.2022962)
# 10171               REDFERN TE  (-33.89293336, 151.2022962)
# 10172               REDFERN TE  (-33.89293336, 151.2022962)
# 10173               REDFERN TE  (-33.89293336, 151.2022962)
# 10174               REDFERN TE  (-33.89293336, 151.2022962)
# 10175               REDFERN TE  (-33.89293336, 151.2022962)
# 10176               REDFERN TE  (-33.89293336, 151.2022962)
# 10177               REDFERN TE  (-33.89293336, 151.2022962)
# 10178               REDFERN TE  (-33.89293336, 151.2022962)
# 10179               REDFERN TE  (-33.89293336, 151.2022962)
# 10180               REDFERN TE  (-33.89293336, 151.2022962)
# 10181               REDFERN TE  (-33.89293336, 151.2022962)
# 10182               REDFERN TE  (-33.89293336, 151.2022962)
# 10183               REDFERN TE  (-33.89293336, 151.2022962)
# 10184               REDFERN TE  (-33.89293336, 151.2022962)
# 10185               REDFERN TE  (-33.89293336, 151.2022962)
# 10186               REDFERN TE  (-33.89293336, 151.2022962)
# 10187               REDFERN TE  (-33.89293336, 151.2022962)
# 10188               REDFERN TE  (-33.89293336, 151.2022962)
# 10189               REDFERN TE  (-33.89293336, 151.2022962)
# 10190               REDFERN TE  (-33.89293336, 151.2022962)
# 10191               REDFERN TE  (-33.89293336, 151.2022962)
# 10192               REDFERN TE  (-33.89293336, 151.2022962)
# 10193               REDFERN TE  (-33.89293336, 151.2022962)
# 10194               REDFERN TE  (-33.89293336, 151.2022962)
# 10195               REDFERN TE  (-33.89293336, 151.2022962)
# 10196               REDFERN TE  (-33.89293336, 151.2022962)
# 10197               REDFERN TE  (-33.89293336, 151.2022962)
# 10198               REDFERN TE  (-33.89293336, 151.2022962)
#
# [2641 rows x 6 columns]

# %% [markdown]
# ### Select comm type

# %%
# put which types you want to select in this list and select from it below
comm_types = ['Phone','SMS','Internet']

df[df['Comm Type'].isin(comm_types)]
# Out:
#                  Datetime Day of Week Comm Identifier Comm Type  \
# 0     2014-04-01 09:40:00     Tuesday      f1a6836c0b     Phone
# 1     2014-04-01 09:42:00     Tuesday      62157ccf29     Phone
# 10453                          REDFERN TE  (-33.89293336, 151.2022962)
# 10454                          REDFERN TE  (-33.89293336, 151.2022962)
# 10455                          REDFERN TE  (-33.89293336, 151.2022962)
# 10456                          REDFERN TE  (-33.89293336, 151.2022962)
# 10457                          REDFERN TE  (-33.89293336, 151.2022962)
# 10458                          REDFERN TE  (-33.89293336, 151.2022962)
# 10459                          REDFERN TE  (-33.89293336, 151.2022962)
# 10460                          REDFERN TE  (-33.89293336, 151.2022962)
# 10461                          REDFERN TE  (-33.89293336, 151.2022962)
# 10462                          REDFERN TE  (-33.89293336, 151.2022962)
# 10463                          REDFERN TE  (-33.89293336, 151.2022962)
# 10464                          REDFERN TE  (-33.89293336, 151.2022962)
# 10465                          REDFERN TE  (-33.89293336, 151.2022962)
# 10466                          REDFERN TE  (-33.89293336, 151.2022962)
# 10467                          REDFERN TE  (-33.89293336, 151.2022962)
# 10468                          REDFERN TE  (-33.89293336, 151.2022962)
# 10469                          REDFERN TE  (-33.89293336, 151.2022962)
# 10470                          REDFERN TE  (-33.89293336, 151.2022962)
# 10471                          REDFERN TE  (-33.89293336, 151.2022962)
# 10472                          REDFERN TE  (-33.89293336, 151.2022962)
# 10473                          REDFERN TE  (-33.89293336, 151.2022962)
# 10474                          REDFERN TE  (-33.89293336, 151.2022962)
# 10475                          REDFERN TE  (-33.89293336, 151.2022962)
#
# [10476 rows x 6 columns]

# %% [markdown]
# ### Look at tower locations and build addresses

# %%
# make a dictionary to store addresses
address={}

# look up addresses and store them in the dictionary
geolocator = Nominatim()
for i in df.Location.unique() :
    location= geolocator.reverse(i)
    address[i]=location.address

# %%
# clean up the address
addressl={}
for k,v in address.items():
    fields=list(v.split(','))
    addressl[k]=fields

# %%
addressl
# Out:
# {(-42.884809999999995, 147.32748000000001): ["Domino's",
#   ' Macquarie Street',
#   ' Hobart',
#   ' Tasmania',
#   ' 7000',
#   ' Australia'],
#  (-42.88194, 147.32893000000001): ['Dôme',
#   ' 29',
#   ' Elizabeth Street',
#   ' Hobart',
#   ' Tasmania',
#   ' 7000',
#   ' Australia'],
#  (-42.881009999999996, 147.33346): ['Hotel Grand Chancellor Hobart',
#   ' 1',
#   ' Davey Street',
#   ' Hobart',
#   ' Tasmania',
#   ' 7000',
#   ' Australia'],
#  (-42.880290000000002, 147.32808): ['Dumpling World',
#   ' Liverpool Street',
#   ' Hobart',
#   ' Tasmania',
#   ' 7000',
#   ' Australia'],
#  (-42.874569999999999, 147.31788): ['Burnett St',
#   ' Burnett Street',
#   ' North Hobart',
#   ' Tasmania',
#   ' 7000',
#   ' Australia'],
#  (-42.860599999999998, 147.45419999999999): ['Mount Rumney Road',
#   ' Acton Park',
#   ' Mount Rumney',
#   ' Tasmania',
#   ' 7019',
#   ' Australia'],
#  (-42.859840000000005, 147.29214999999999): ['William Cooper Drive',
#   ' New Town',
#   ' Tasmania',
#   ' 7008',
#   ' Australia'],
#  (-42.853070000000002, 147.31531999999999): ['Tasmanian Hockey Centre',
#   ' Brooker Highway',
#   ' Lutana',
#   ' Tasmania',
#   ' 7008',
#   ' Australia'],
#  (-42.843379999999996, 147.29568999999998): ['Intercity Cycleway',
#   ' Moonah',
#   ' Tasmania',
#   ' 7009',
#   ' Australia'],
#  (-42.837620000000001, 147.50575000000001): ['Hertz',
#   ' Passenger Pick-Up',
#   ' Seven Mile Beach',
#   ' Midway Point',
#   ' Tasmania',
#   ' 7170',
#   ' Australia'],
#  (-42.828420000000001, 147.30784): ['NyrStar',
#   ' Lutana',
#   ' Tasmania',
#   ' 7009',
#   ' Australia'],
#  (-37.792900000000003, 144.96872999999999): ['Lygon Street',
#   ' Carlton',
#   ' Melbourne',
#   ' City of Melbourne',
#   ' Greater Melbourne',
#   ' Victoria',
#   ' 3000',
#   ' Australia'],
#  (-37.777799999999999, 144.93000000000001): ['The Laurel Hotel',
#   ' 289',
#   ' Mount Alexander Road',
#   ' Travancore',
#   ' City of Moonee Valley',
#   ' Greater Melbourne',
#   ' Victoria',
#   ' 3032',
#   ' Australia'],
#  (-37.670417999999998, 144.848243): ['T3 Domestic - Virgin Australia',
#   ' Departure Drive',
#   ' Melbourne Airport',
#   ' City of Hume',
#   ' Greater Melbourne',
#   ' Victoria',
#   ' 3045',
#   ' Australia'],
#  (-36.502179999999996, 146.11177000000001): ['Benalla - Winton Road',
#   ' Glenrowan',
#   ' Rural City of Benalla',
#   ' Hume',
#   ' Victoria',
#   ' 3675',
#   ' Australia'],
#  (-36.356699999999996, 146.71360000000001): ['Red Hill Road',
#   ' Beechworth',
#   ' Shire of Indigo',
#   ' Hume',
#   ' Victoria',
#   ' 3747',
#   ' Australia'],
#  (-36.331074999999998, 146.07543200000001): ['Thoona Road',
#   ' Taminick',
#   ' Thoona',
#   ' Rural City of Benalla',
#   ' Hume',
#   ' Victoria',
#   ' Australia'],
#  (-36.167929999999998, 146.88306): ['Beechworth - Wodonga Road',
#   ' Leneva',
#   ' Wodonga',
#   ' Hume',
#   ' Victoria',
#   ' 3690',
#   ' Australia'],
#  (-33.946740000000005, 151.16713999999999): ['77',
#   ' Kyeemagh Avenue',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.937558000000003, 151.16569999999999): ['Terminal 1 - International',
#   ' Departure Plaza',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.934674000000001, 151.16451999999998): ['International P7',
#   ' Arrival Court',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.934159999999999, 151.17938000000001): ["McDonald's",
#   ' Keith Smith Avenue',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.932850000000002, 151.1842): ['Seventh Street',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.924799, 151.18804299999999): ['TNT',
#   ' Coward Street',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.923217000000001, 151.18734499999999): ['Mascot Towers',
#   ' Bourke Street',
#   ' Mascot',
#   ' Sydney',
#   ' Bayside Council',
#   ' NSW',
#   ' 2020',
#   ' Australia'],
#  (-33.911320000000003, 151.20394999999999): ['Dunning Avenue',
#   ' Rosebery',
#   ' Sydney',
#   ' NSW',
#   ' 2018',
#   ' Australia'],
#  (-33.905329999999999, 151.205781): ['Christies Lane',
#   ' Zetland',
#   ' Sydney',
#   ' NSW',
#   ' 2017',
#   ' Australia'],
#  (-33.896050000000002, 151.17963999999998): ['Marys',
#   ' Mary Street',
#   ' Newtown',
#   ' Sydney',
#   ' NSW',
#   ' 2042',
#   ' Australia'],
#  (-33.892933360000001, 151.20229619999998): ['Redfern Telstra Exchange',
#   ' 103-109',
#   ' George Street',
#   ' Redfern',
#   ' Sydney',
#   ' NSW',
#   ' 2016',
#   ' Australia'],
#  (-33.892330000000001, 151.21653000000001): ['The Bat & Ball Hotel',
#   ' Cleveland Street',
#   ' Surry Hills',
#   ' Sydney',
#   ' NSW',
#   ' 2010',
#   ' Australia'],
#  (-33.88964, 151.21142): ['Marlborough Street',
#   ' Surry Hills',
#   ' Sydney',
#   ' NSW',
#   ' 2010',
#   ' Australia'],
#  (-33.886400000000002, 151.2088): ['418A',
#   ' Elizabeth Street',
#   ' Surry Hills',
#   ' Sydney',
#   ' NSW',
#   ' 2010',
#   ' Australia'],
#  (-33.884603000000006, 151.19564299999999): ['184-200',
#   ' Broadway',
#   ' Chippendale',
#   ' Sydney',
#   ' NSW',
#   ' 2008',
#   ' Australia'],
#  (-33.884171029999997, 151.20235): ['824-826',
#   ' George Street',
#   ' Haymarket',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.880580000000002, 151.20046000000002): ["Hippo's On Harris",
#   ' Harris Street',
#   ' Ultimo',
#   ' Sydney',
#   ' NSW',
#   ' 2007',
#   ' Australia'],
#  (-33.880328910000003, 151.20569040000001): ['Parker Street Exchange',
#   ' Parker Lane',
#   ' Haymarket',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.880240000000001, 151.20569): ['Parker Street Exchange',
#   ' Parker Lane',
#   ' Haymarket',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.87932, 151.23802000000001): ['Federal Member for Wentworth',
#   ' Honorable Malcolm Turnbull MP',
#   ' Prime Minister of Australia',
#   ' 287-289',
#   ' New South Head Road',
#   ' Edgecliff',
#   ' Sydney',
#   ' Woollahra',
#   ' NSW',
#   ' 2027',
#   ' Australia'],
#  (-33.878999999999998, 151.19801000000001): ['349-357',
#   ' Bulwara Road',
#   ' Ultimo',
#   ' Sydney',
#   ' NSW',
#   ' 2007',
#   ' Australia'],
#  (-33.87829, 151.20345): ['Holiday Inn Darling Harbour',
#   ' 68',
#   ' Harbour Street',
#   ' Haymarket',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.878140000000002, 151.21360000000001): ['Burger King',
#   ' Pelican Street',
#   ' Darlinghurst',
#   ' Sydney',
#   ' NSW',
#   ' 2010',
#   ' Australia'],
#  (-33.875129999999999, 151.20583999999999): ['Event',
#   ' 505-525',
#   ' George Street',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.872149999999998, 151.20614): ['Palings',
#   ' Mullins Street',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.870550000000001, 151.20793): ['The Tower',
#   ' Pitt Street Mall',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.8703, 151.21010000000001): ['David Johnes Department Store',
#   ' Castlereagh Street',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.866549999999997, 151.21033): ['Consulate-General of New Zealand',
#   ' 55',
#   ' Hunter Street',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.866329999999998, 151.20469): ['Kent Telephone Exchange',
#   ' 97-105',
#   ' Kent Street',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.862850000000002, 151.20842999999999): ['Dalley Street Substation',
#   ' 6',
#   ' Dalley Street',
#   ' The Rocks',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.861129999999996, 151.21293): ['Quay Grand',
#   ' Cahill Walk',
#   ' Sydney CBD',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.859470000000002, 151.20748999999998): ['Clocktower Square',
#   ' Harrington Street',
#   ' The Rocks',
#   ' Sydney',
#   ' NSW',
#   ' 2000',
#   ' Australia'],
#  (-33.834150000000001, 151.20889): ['Rydges Horth Sydney',
#   ' Elliot Street',
#   ' Victoria Cross',
#   ' North Sydney',
#   ' Lower North Shore',
#   ' Sydney',
#   ' North Sydney',
#   ' NSW',
#   ' 2060',
#   ' Australia'],
#  (-33.830959999999997, 151.22548999999998): ['272',
#   ' Military Road',
#   ' Cremorne',
#   ' Lower North Shore',
#   ' Sydney',
#   ' North Sydney',
#   ' NSW',
#   ' 2090',
#   ' Australia'],
#  (-33.8294, 151.21827999999999): ['Neutral Bay Medical Centre',
#   ' Military Road',
#   ' Neutral Bay',
#   ' Lower North Shore',
#   ' Sydney',
#   ' North Sydney',
#   ' NSW',
#   ' 2089',
#   ' Australia'],
#  (-33.828072999999996, 151.22627499999999): ['Gerard Lane',
#   ' Cremorne',
#   ' Lower North Shore',
#   ' Sydney',
#   ' North Sydney',
#   ' NSW',
#   ' 2090',
#   ' Australia'],
#  (-33.806379999999997,
#   151.24698000000001): ['Marine Rescue Sydney - Middle Harbour', ' Parriwi Road', ' Mosman', ' Lower North Shore', ' Sydney', ' Mosman', ' NSW', ' 2088', ' Australia'],
#  (-33.799479999999996, 151.28933999999998): ['Manly Wine',
#   ' South Steyne',
#   ' Manly',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2095',
#   ' Australia'],
#  (-33.796678999999997, 151.285293): ['Manly Congregational Church',
#   ' Whistler Street',
#   ' Manly',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2095',
#   ' Australia'],
#  (-33.796610000000001, 151.27756000000002): ["Avo's Auto Repairs",
#   ' 126',
#   ' Sydney Road',
#   ' Fairlight',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2094',
#   ' Australia'],
#  (-33.793647999999997,
#   151.26393400000001): ['The Village - Balgowlah Stockland', ' Pedestrian path', ' Balgowlah', ' Northern Beaches', ' Sydney', ' Northern Beaches', ' NSW', ' 2093', ' Australia'],
#  (-33.79345, 151.26310000000001): ["Porter's Liquor",
#   ' Sydney Road',
#   ' Balgowlah',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2093',
#   ' Australia'],
#  (-33.792749999999998, 151.24125000000001): ['Little Dove',
#   ' Frenchs Forest Road',
#   ' Seaforth',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2092',
#   ' Australia'],
#  (-33.791965000000005, 151.28658899999999): ['Honolulu grill',
#   ' North Steyne',
#   ' Manly',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2095',
#   ' Australia'],
#  (-33.788150000000002, 151.26653999999999): ['Hayes Street',
#   ' Balgowlah',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2093',
#   ' Australia'],
#  (-33.779333000000001, 151.27690100000001): ['Waine Street',
#   ' Freshwater',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2096',
#   ' Australia'],
#  (-33.75949, 151.28135): ['Pittwater Road',
#   ' Dee Why Beach',
#   ' Dee Why',
#   ' Northern Beaches',
#   ' Sydney',
#   ' Northern Beaches',
#   ' NSW',
#   ' 2099',
#   ' Australia'],
#  (-33.71763, 151.11658): ['Telstra Exchange',
#   ' Station Lane',
#   ' Wahroonga',
#   ' Sydney',
#   ' Ku-ring-gai',
#   ' NSW',
#   ' 2076',
#   ' Australia'],
#  (-33.63599, 151.14689999999999): ['Windybanks Interchange',
#   ' Berowra',
#   ' Sydney',
#   ' Hornsby',
#   ' NSW',
#   ' 2081',
#   ' Australia'],
#  (-33.6038, 151.16390000000001): ['Old Pacific Highway',
#   ' Cowan',
#   ' Sydney',
#   ' Hornsby',
#   ' NSW',
#   ' 2081',
#   ' Australia'],
#  (-33.578389999999999, 151.18445): ['Old Pacific Highway',
#   ' Cowan',
#   ' Sydney',
#   ' Hornsby',
#   ' NSW',
#   ' 2081',
#   ' Australia'],
#  (-33.557310000000001, 151.19353000000001): ['Old Pacific Highway',
#   ' Brooklyn',
#   ' Kangaroo Point',
#   ' Sydney',
#   ' Hornsby',
#   ' NSW',
#   ' 2083',
#   ' Australia']}

# %%
# make a field for each part of the address to sort and show

# df['address']=df.Location.map(lambda x: address[x])
df['Place']=df.Location.map(lambda x: addressl[x][0])
df['Town']=df.Location.map(lambda x: addressl[x][-4])
df['Region']=df.Location.map(lambda x: addressl[x][-3])
df['Zip']=df.Location.map(lambda x: addressl[x][-2])
df['Country']=df.Location.map(lambda x: addressl[x][-1])

# %%
# what unique regions has he/she visited?

df['Region'].unique()
# Out:
# array([' NSW', ' Tasmania', ' Victoria', ' Hume'], dtype=object)

# %% [markdown]
# ### Select hour groupings (night, work, after work)

# %%
# from midnight to 8am
df[df.Datetime.dt.hour < 8]

# select top locations for this time period
df[df.Datetime.dt.hour < 8]['Location'].value_counts().head()
# Out:
# (-33.78815, 151.26654)         743
# (-33.88417103, 151.20235)      128
# (-33.79661, 151.27756)          48
# (-33.779333, 151.276901)        45
# (-33.88032891, 151.2056904)     40
# Name: Location, dtype: int64

# %%
# from 8am-5pm
df[(df.Datetime.dt.hour > 7) & (df.Datetime.dt.hour < 17)]

# select top locations for this time period
df[(df.Datetime.dt.hour > 7) & (df.Datetime.dt.hour < 17)]['Location'].value_counts().head()
# Out:
# (-33.78815, 151.26654)         1758
# (-33.88417103, 151.20235)       685
# (-33.88032891, 151.2056904)     407
# (-42.84338, 147.29569)          378
# (-33.89293336, 151.2022962)     241
# Name: Location, dtype: int64

# %%
# from 5pm-midnight
df[(df.Datetime.dt.hour > 16)]

# select top locations for this time period
df[(df.Datetime.dt.hour > 16)]['Location'].value_counts().head()
# Out:
# (-33.78815, 151.26654)         1800
# (-33.89293336, 151.2022962)     450
# (-42.84338, 147.29569)          338
# (-33.88417103, 151.20235)       271
# (-42.85984, 147.29215)          262
# Name: Location, dtype: int64

# %% [markdown]
# ### Plot on the map!

# %%
# access each location by index, and then index inside the tuple
display(df.Location.iloc[5][0])
display(df.Location.iloc[5][1])
# Out:
# -33.884171029999997
# 151.20235

# %%
# plotting code here is just an example - I'm not plotting every combination above
# in this case, we're just plotting all 70 unique locations

map_location = folium.Map(location=[-35.136188, 150.612841], zoom_start = 5)

for x in df.Location.unique():
    folium.Marker((x[0], x[1]), popup='It worked!').add_to(map_location)
map_location
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### add these to a heatmap showing frequency at locations

# %%
from folium.plugins import HeatMap, HeatMapWithTime

# initialize heatmap, add center point
heatmap_location = folium.Map(location=[-35.136188, 150.612841], zoom_start = 5)

# add the location column to map
HeatMap(df.Location).add_to(heatmap_location)

# %%
heatmap_location
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Most Frequent Contacts

# %%
df['Comm Identifier'].dropna().value_counts().head(10)
# Out:
# bc0b018604    219
# 12e3d1b0c9    146
# 91aba4a113    144
# a24a4646d0    133
# 6bbc17070a     83
# a804558e42     62
# cd3b394668     56
# c22670da93     44
# 70e1f163d8     39
# c521537546     31
# Name: Comm Identifier, dtype: int64
