# %% [markdown]
# # Bonus lesson: Using NearestNeighbors to analyze soccer and city data

# %% [markdown]
# In this extracurricular lesson, we'll be using the NearestNeighbors algorithm (obviously very similar to KNN) to find soccer player who are similar to one another. Then we'll use it to determine which city Amazon should choose as it's second national headquarters.

# %% [markdown]
# This is also bit of a lesson in recommendation systems because we'll be "recommending" cities and players.

# %% [markdown]
# ## FIFA Player Data
#
# Dataset information:https://www.kaggle.com/thec03u5/fifa-18-demo-player-dataset

# %%
#Imports
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
pd.set_option("max.columns", 35)

# %%
fifa = pd.read_csv("../data/fifa_data.csv")
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    Height Weight Preffered_Foot  Birth_Date  Age Preffered_Position  \
# 0  185 cm  80 kg          Right  02/05/1985   32              LW/ST
# 1  170 cm  72 kg           Left  06/24/1987   29                 RW
# 2  174 cm  68 kg          Right  02/05/1992   25                 LW
# 3  182 cm  85 kg          Right  01/24/1987   30                 ST
# 4  193 cm  92 kg          Right  03/27/1986   31                 GK
#
#          Work_Rate     ...       Strength  Balance  Agility  Jumping  Heading  \
# 0       High / Low     ...             80       63       90       95       85
# 1  Medium / Medium     ...             59       95       90       68       71
# 2    High / Medium     ...             49       82       96       61       62
# 3    High / Medium     ...             76       60       86       69       77
# 4  Medium / Medium     ...             83       35       52       78       25
#
#    Shot_Power  Finishing  Long_Shots  Curve  Freekick_Accuracy  Penalties  \
# 0          92         93          90     81                 76         85
# 1          85         95          88     89                 90         74
# 2          78         89          77     79                 84         81
# 3          87         94          86     86                 84         85
# 4          25         13          16     14                 11         47
#
#    Volleys  GK_Positioning  GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0       88              14          7          15           11           11
# 1       85              14          6          15           11            8
# 2       83              15          9          15            9           11
# 3       88              33         27          31           25           37
# 4       11              91         89          95           90           89
#
# [5 rows x 53 columns]

# %% [markdown]
# Data cleaning time. I'm going to filter the data down to just the attributes and players who are not goalkeepers.

# %%
#Set name as index
fifa.set_index("Name", inplace=True)
#Drop goal keeepers
fifa = fifa[fifa.Club_Position != "GK"].copy()
#List of columns to drop.
cols = ['Nationality', 'National_Position', 'National_Kit', 'Club','Club_Position',
        'Club_Kit', 'Club_Joining', 'Contract_Expiry', 'Height',
        'Weight', 'Preffered_Foot', 'Birth_Date', 'Age',
        'Preffered_Position', 'Work_Rate', "GK_Positioning", "GK_Diving", "GK_Kicking",
       "GK_Handling", "GK_Reflexes"]
#Drop these columns
fifa.drop(cols, axis = 1, inplace=True)
#lower case column names
fifa.columns = fifa.columns.str.lower()

fifa.head()
# Out:
#                     rating  weak_foot  skill_moves  ball_control  dribbling  \
# Name
# Cristiano Ronaldo       94          4            5            93         92
# Lionel Messi            93          4            4            95         97
# Neymar                  92          5            5            95         96
# Luis Suárez             92          4            4            91         86
# Robert Lewandowski      90          4            3            87         85
#
#                     marking  sliding_tackle  standing_tackle  aggression  \
# Name
# Cristiano Ronaldo        22              23               31          63
# Lionel Messi             13              26               28          48
# Neymar                   21              33               24          56
# Luis Suárez              30              38               45          78
# Robert Lewandowski       25              19               42          80
#
#                     reactions  attacking_position  interceptions  vision  \
# Name
# Cristiano Ronaldo          96                  94             29      85
# Lionel Messi               95                  93             22      90
# Neymar                     88                  90             36      80
# Luis Suárez                93                  92             41      84
# Robert Lewandowski         88                  89             39      78
#
#                     composure  crossing  short_pass  long_pass  acceleration  \
# Name
# Cristiano Ronaldo          86        84          83         77            91
# Lionel Messi               94        77          88         87            92
# Neymar                     80        75          81         75            93
# Luis Suárez                83        77          83         64            88
# Robert Lewandowski         87        62          83         65            79
#
#                     speed  stamina  strength  balance  agility  jumping  \
# Name
# Cristiano Ronaldo      92       92        80       63       90       95
# Lionel Messi           87       74        59       95       90       68
# Neymar                 90       79        49       82       96       61
# Luis Suárez            77       89        76       60       86       69
# Robert Lewandowski     82       79        84       79       78       84
#
#                     heading  shot_power  finishing  long_shots  curve  \
# Name
# Cristiano Ronaldo        85          92         93          90     81
# Lionel Messi             71          85         95          88     89
# Neymar                   62          78         89          77     79
# Luis Suárez              77          87         94          86     86
# Robert Lewandowski       85          86         91          82     77
#
#                     freekick_accuracy  penalties  volleys
# Name
# Cristiano Ronaldo                  76         85       88
# Lionel Messi                       90         74       85
# Neymar                             84         81       83
# Luis Suárez                        84         85       88
# Robert Lewandowski                 76         81       86

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16956 entries, Cristiano Ronaldo to Barry Richardson
# Data columns (total 32 columns):
# rating                16956 non-null int64
# weak_foot             16956 non-null int64
# skill_moves           16956 non-null int64
# ball_control          16956 non-null int64
# dribbling             16956 non-null int64
# marking               16956 non-null int64
# sliding_tackle        16956 non-null int64
# standing_tackle       16956 non-null int64
# aggression            16956 non-null int64
# reactions             16956 non-null int64
# attacking_position    16956 non-null int64
# interceptions         16956 non-null int64
# vision                16956 non-null int64
# composure             16956 non-null int64
# crossing              16956 non-null int64
# short_pass            16956 non-null int64
# long_pass             16956 non-null int64
# acceleration          16956 non-null int64
# speed                 16956 non-null int64
# stamina               16956 non-null int64
# strength              16956 non-null int64
# balance               16956 non-null int64
# agility               16956 non-null int64
# jumping               16956 non-null int64
# heading               16956 non-null int64
# shot_power            16956 non-null int64
# finishing             16956 non-null int64
# long_shots            16956 non-null int64
# curve                 16956 non-null int64
# freekick_accuracy     16956 non-null int64
# penalties             16956 non-null int64
# volleys               16956 non-null int64
# dtypes: int64(32)
# memory usage: 4.3+ MB

# %% [markdown]
# We now have a dataset of 16956 players and 32 attributes. For the purpose of this exercise I am going to reduce the size of thise dataset by filtering out players whose "Rating" value is less than 70.

# %%
fifa = fifa[fifa.rating >= 70]
fifa.shape
# Out:
# (5232, 32)

# %% [markdown]
# Now we have 5232 players

# %%
#Drop the rating column
fifa.drop("rating", axis = 1, inplace= True)

# %%
fifa.head()
# Out:
#                     weak_foot  skill_moves  ball_control  dribbling  marking  \
# Name
# Cristiano Ronaldo           4            5            93         92       22
# Lionel Messi                4            4            95         97       13
# Neymar                      5            5            95         96       21
# Luis Suárez                 4            4            91         86       30
# Robert Lewandowski          4            3            87         85       25
#
#                     sliding_tackle  standing_tackle  aggression  reactions  \
# Name
# Cristiano Ronaldo               23               31          63         96
# Lionel Messi                    26               28          48         95
# Neymar                          33               24          56         88
# Luis Suárez                     38               45          78         93
# Robert Lewandowski              19               42          80         88
#
#                     attacking_position  interceptions  vision  composure  \
# Name
# Cristiano Ronaldo                   94             29      85         86
# Lionel Messi                        93             22      90         94
# Neymar                              90             36      80         80
# Luis Suárez                         92             41      84         83
# Robert Lewandowski                  89             39      78         87
#
#                     crossing  short_pass  long_pass  acceleration  speed  \
# Name
# Cristiano Ronaldo         84          83         77            91     92
# Lionel Messi              77          88         87            92     87
# Neymar                    75          81         75            93     90
# Luis Suárez               77          83         64            88     77
# Robert Lewandowski        62          83         65            79     82
#
#                     stamina  strength  balance  agility  jumping  heading  \
# Name
# Cristiano Ronaldo        92        80       63       90       95       85
# Lionel Messi             74        59       95       90       68       71
# Neymar                   79        49       82       96       61       62
# Luis Suárez              89        76       60       86       69       77
# Robert Lewandowski       79        84       79       78       84       85
#
#                     shot_power  finishing  long_shots  curve  \
# Name
# Cristiano Ronaldo           92         93          90     81
# Lionel Messi                85         95          88     89
# Neymar                      78         89          77     79
# Luis Suárez                 87         94          86     86
# Robert Lewandowski          86         91          82     77
#
#                     freekick_accuracy  penalties  volleys
# Name
# Cristiano Ronaldo                  76         85       88
# Lionel Messi                       90         74       85
# Neymar                             84         81       83
# Luis Suárez                        84         85       88
# Robert Lewandowski                 76         81       86

# %% [markdown]
# Scaling time.

# %%
#Fit transform data using StandardScaler

ss = StandardScaler()
fifa_ss = ss.fit_transform(fifa)

# %%
#Convert to data frame
fifa_ss = pd.DataFrame(fifa_ss, index=fifa.index, columns= fifa.columns)
fifa_ss.head(30)
# Out:
#                            weak_foot  skill_moves  ball_control  dribbling  \
# Name
# Cristiano Ronaldo           1.277111     3.097341      1.941744   1.731423
# Lionel Messi                1.277111     1.806906      2.103142   2.053962
# Neymar                      2.733485     3.097341      2.103142   1.989454
# Luis Suárez                 1.277111     1.806906      1.780346   1.344378
# Robert Lewandowski          1.277111     0.516470      1.457550   1.279870
# Gareth Bale                -0.179263     1.806906      1.538249   1.537900
# Zlatan Ibrahimović          1.277111     1.806906      1.699647   1.408885
# Diego Godín                2.040836    0.019379  -0.669432   -0.913424
# Mats Hummels               1.906999    0.301607   0.033897   -0.448385
# Giorgio Chiellini          1.237813    0.795507  -1.156352   -0.564645
# Philipp Lahm               0.100199   -0.686192  -0.398921    0.365434
# Pepe                       1.371650   -0.262849  -0.453023   -0.157735
# Iniesta                   -0.502068   -0.121735   1.007736    0.888603
# James Rodríguez            0.033280    1.359964   1.494656    1.876812
# Pierre-Emerick Aubameyang  1.170895    1.007178   1.819269    1.179253
# Leonardo Bonucci           1.505487    0.513279  -0.939943    0.365434
#
#                               curve  freekick_accuracy  penalties   volleys
# Name
# Cristiano Ronaldo          1.318979           1.307741   1.879504  1.991155
# Lionel Messi               1.782492           2.117156   1.136338  1.819532
# Neymar                     1.203101           1.770264   1.609262  1.705117
# Luis Suárez                1.608675           1.770264   1.879504  1.991155
# Robert Lewandowski         1.087223           1.307741   1.609262  1.876740
# Gareth Bale                1.608675           1.828079   1.271459  1.304664
# Zlatan Ibrahimović         1.376918           1.654633   2.284867  2.277192
# Jérôme Boateng            -0.129499          -1.293950  -0.755355 -0.011109
# Eden Hazard                1.376918           1.481187   1.947064  1.476287
# Luka Modrić                1.203101           1.365556   1.541701  1.190249
# Mesut Özil                 1.492796           1.481187   0.663415  1.361872
# Gonzalo Higuaín            0.913405           0.498326   0.866096  1.991155
# Thiago Silva               0.160196           1.134295   0.933657  0.560966
# Sergio Ramos               0.855466           0.787403   0.730975  0.732589
# Sergio Agüero              1.376918           1.076479   1.541701  1.819532
# Paul Pogba                 1.376918           1.654633   1.271459  1.762325
# Antoine Griezmann          1.492796           1.249925   0.933657  1.933947
# Kevin De Bruyne            1.318979           1.770264   1.339020  1.647910
# Marco Reus                 1.840431           1.770264   1.811943  1.991155
# Alexis Sánchez             1.145162           1.423372   1.339020  1.705117
# Toni Kroos                 1.550736           1.770264   1.068778  1.647910
# Diego Godín               -0.535073          -0.137643  -0.485113 -0.354354
# Mats Hummels               0.391953          -0.022012   0.730975  0.389344
# Giorgio Chiellini          0.102257          -1.293950  -0.485113 -0.468769
# Philipp Lahm               1.087223           0.324880   0.798536  0.732589
# Pepe                      -0.824769          -0.368904  -0.012190 -1.727335
# Iniesta                    1.261040           0.960849   0.933657  1.190249
# James Rodríguez            1.666614           1.885894   1.609262  2.162777
# Pierre-Emerick Aubameyang  1.145162           1.192110   1.676822  1.876740
# Leonardo Bonucci          -0.129499           0.440511   0.866096  0.103306

# %% [markdown]
# We now have a scaled data frame of the fifa attributes for 5000+ players. We're going to use this data to find which players are similar to one another.

# %%
#Initialize the NearestNeighbors algorithm with 6 neighbors and metric = euclidena
nn = NearestNeighbors(n_neighbors=6, metric="euclidean")

#Fit nn on the fifa_ss data
nn.fit(fifa_ss)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='euclidean',
#          metric_params=None, n_jobs=1, n_neighbors=6, p=2, radius=1.0)

# %% [markdown]
# Uses the euclidean distance formula to calculate distances between the player vectors. The shorter the distance between two players, the more similar they are.

# %%
#Assign data from players to variables

#Pogba is midfielder
pogba = fifa_ss.loc["Paul Pogba",].values.reshape(1, -1)
#Neymar is a forward
neymar = fifa_ss.loc["Neymar", ].values.reshape(1, -1)
#Chiellini is a defender
chiellini = fifa_ss.loc["Giorgio Chiellini",].values.reshape(1, -1)

# %% [markdown]
# Use the kneighbors method to find the neighbors for each player

# %%
#Pass player variables in to nn.kneighbors

pogba_neighbors = nn.kneighbors(pogba)
neymar_neighbors = nn.kneighbors(neymar)
chiellini_neighbors = nn.kneighbors(chiellini)

# %%
#We can also pass in the whole dataset into nn object
everyones_neighbors = nn.kneighbors(fifa_ss)

# %%
#Look at pogba_neighbors
pogba_neighbors
# Out:
# (array([[ 0.        ,  3.35874646,  3.69872742,  3.7555846 ,  3.8697611 ,
#           3.89096401]]), array([[ 15,  49, 227, 446, 102,   5]]))

# %% [markdown]
# This outputs two numpy arrays.

# %%
#Array number one
pogba_neighbors[0]
# Out:
# array([[ 0.        ,  3.35874646,  3.69872742,  3.7555846 ,  3.8697611 ,
#          3.89096401]])

# %% [markdown]
# These are the distances between Paul Pogba and the six closest neighbors. You'll notice that there's a 0 and that's because Paul Pogba is already in the data, so naturally Paul Pogba is gonna be closest to Paul Pogba.

# %%
#Array number two
pogba_neighbors[1]
# Out:
# array([[ 15,  49, 227, 446, 102,   5]])

# %% [markdown]
# These are the index values of the 6 closest neighbors to Paul Pogba.

# %% [markdown]
# Let's use these index values to see the closest players to Pogba.

# %%
#Create variable for index values of the closest players to pogba
pogba_neighbors_index = pogba_neighbors[1][0]

# %%
#Pass pogba_neighbors_index into the fifa_ss dataframe and call .index to only returns names
fifa_ss.iloc[pogba_neighbors_index,].index
# Out:
# Index([u'Paul Pogba', u'Claudio Marchisio', u'Axel Witsel',
#        u'Kevin-Prince Boateng', u'Arda Turan', u'Gareth Bale'],
#       dtype='object', name=u'Name')

# %% [markdown]
# These are the 5 closest players to Paul Pogba (ignoring Paul Pogba of course).

# %% [markdown]
# Let's do this again for Neymar and Chiellini

# %%
#Neymar
neymar_neighbors_index = neymar_neighbors[1][0]
fifa_ss.iloc[neymar_neighbors_index,].index
# Out:
# Index([u'Neymar', u'Eden Hazard', u'Ousmane Dembélé', u'Franck Ribéry',
#        u'Giovani dos Santos', u'Pedro'],
#       dtype='object', name=u'Name')

# %%
chiellini_neighbors_index = chiellini_neighbors[1][0]
fifa_ss.iloc[chiellini_neighbors_index,].index
# Out:
# Index([u'Giorgio Chiellini', u'Sokratis', u'Marvin Matip', u'Miranda',
#        u'Marcos Angeleri', u'Andrea Barzagli'],
#       dtype='object', name=u'Name')

# %% [markdown]
# ## Amazon

# %% [markdown]
# My article about how I used this algorithm to determine which city Amazon should choose as the home of its second HQ: https://www.thinkful.com/blog/data-science-just-figured-out-where-amazons-hq2-should-be/

# %%
#Load in data, which is a pickle file

cities = pd.read_csv("../data/amazon_cities_data.csv", index_col="cities")
cities.head()
# Out:
#            sprawl  diversity  business_score  fiber_coverage  \
# cities
# Atlanta     41.00      67.26             4.0            11.2
# Austin     102.44      69.91             3.7            12.1
# Baltimore  115.62      64.92             1.7            60.2
# Boston     126.93      68.96             3.0            38.8
# Charlotte   70.45      69.56             3.3            11.3
#
#            excellent_education  percent_bachelors  life_quality  \
# cities
# Atlanta                      2               35.8           6.6
# Austin                       1               41.7           7.8
# Baltimore                    2               37.3           6.3
# Boston                       7               44.6           7.1
# Charlotte                    0               32.2           7.1
#
#            mobile_network_score  transit_scores
# cities
# Atlanta                    97.2            7.70
# Austin                     97.2            5.47
# Baltimore                  96.6            8.52
# Boston                     95.3            9.44
# Charlotte                  95.8            4.33

# %% [markdown]
# This data definitely needs scaling

# %%
#Intialize scaler
ss = StandardScaler()

#Fit and transform data using scaler
cities_ss = ss.fit_transform(cities)

cities_ss = pd.DataFrame(cities_ss, index=cities.index, columns=cities.columns)
cities_ss.head()
# Out:
#              sprawl  diversity  business_score  fiber_coverage  \
# cities
# Atlanta   -1.922780  -0.068233        1.198111       -0.627189
# Austin    -0.062954   0.908403        0.890527       -0.564271
# Baltimore  0.336012  -0.930621       -1.160029        2.798383
# Boston     0.678373   0.558288        0.172833        1.302317
# Charlotte -1.031311   0.779413        0.480416       -0.620198
#
#            excellent_education  percent_bachelors  life_quality  \
# cities
# Atlanta               0.391040           0.304105     -0.079936
# Austin               -0.260694           1.330209      2.318146
# Baltimore             0.391040           0.564979     -0.679457
# Boston                3.649711           1.834566      0.919265
# Charlotte            -0.912428          -0.321993      0.919265
#
#            mobile_network_score  transit_scores
# cities
# Atlanta                0.687416        0.347833
# Austin                 0.687416       -0.976476
# Baltimore             -0.006610        0.834798
# Boston                -1.510333        1.381150
# Charlotte             -0.931978       -1.653477

# %% [markdown]
# First we need to determine the best city. I did by creating an array with the max values for each column.

# %%
best_city = cities_ss.max()
best_city
# Out:
# sprawl                  2.991955
# diversity               1.579149
# business_score          1.505694
# fiber_coverage          2.798383
# excellent_education     3.649711
# percent_bachelors       2.582405
# life_quality            2.318146
# mobile_network_score    1.497114
# transit_scores          1.476167
# dtype: float64

# %% [markdown]
# This technique assumes that more = equals better. For example if we had a feature such as rate of cancer, then that would present an issue here because the lower the rate, the better the value.

# %% [markdown]
# Time to fit the data on a NearestNeighbors object

# %%
#Intialize algorithm with 5 neighbors
nn = NearestNeighbors(n_neighbors=5, metric="euclidean")
#Fit data
nn.fit(cities_ss)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='euclidean',
#          metric_params=None, n_jobs=1, n_neighbors=5, p=2, radius=1.0)

# %%
#Pass in best city to see the top five closest cities

best_city_neighbors_index = nn.kneighbors(best_city.values.reshape(1, -1))[1][0]

# %%
#Pass in best_city_neighbors_index object into cities_ss
cities_ss.iloc[best_city_neighbors_index,].index
# Out:
# Index([u'Washington DC', u'Boston', u'New York', u'Philadelphia', u'Austin'], dtype='object', name=u'cities')

# %% [markdown]
# Washington DC is the winner of the 2017 Amazon HQ sweepstakes!!!
# <br><br>
# Boston comes in 2nd, and New York in 3rd.
